# %% [markdown]
# # Paso 1

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.14-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 1.6 MB/s eta 0:00:011
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: appdirs>=1.4.4 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.26 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.27.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.6-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.4.2)
# Collecting pytz>=2022.5
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: cryptography>=3.3.2 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (3.4.8)
# Collecting lxml>=4.9.1
#   Downloading lxml-4.9.2-cp39-cp39-macosx_10_15_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: pycparser in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: six>=1.9 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.3)
# Installing collected packages: pytz, multitasking, lxml, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Uninstalling pytz-2021.3:
#       Successfully uninstalled pytz-2021.3
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.8.0
#     Uninstalling lxml-4.8.0:
#       Successfully uninstalled lxml-4.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# Successfully installed frozendict-2.3.6 html5lib-1.1 lxml-4.9.2 multitasking-0.0.11 pytz-2023.3 yfinance-0.2.14

# %% [markdown]
# # Paso 2

# %%
import yfinance as yf
pfe = yf.Ticker('TSLA')
pfe.info
# Out:
# {'symbol': 'TSLA',
#  'twoHundredDayAverageChangePercent': -0.13381894,
#  'averageAnalystRating': '2.4 - Buy',
#  'fiftyTwoWeekLowChangePercent': 0.8336961,
#  'language': 'en-US',
#  'earningsTimestampEnd': 1682337600,
#  'regularMarketDayRange': '183.76 - 190.68',
#  'epsForward': 5.47,
#  'regularMarketDayHigh': 190.68,
#  'twoHundredDayAverageChange': -28.842087,
#  'twoHundredDayAverage': 215.53069,
#  'askSize': 10,
#  'bookValue': 14.129,
#  'fiftyTwoWeekHighChange': -177.38474,
#  'marketCap': 590701395968,
#  'fiftyTwoWeekRange': '101.81 - 364.07333',
#  'fiftyDayAverageChange': -3.0207977,
#  'averageDailyVolume3Month': 173107995,
#  'firstTradeDateMilliseconds': 1277818200000,
#  'exchangeDataDelayedBy': 0,
#  'trailingAnnualDividendRate': 0.0,
#  'fiftyTwoWeekLow': 101.81,
#  'regularMarketVolume': 101889547,
#  'market': 'us_market',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'messageBoardId': 'finmb_27444752',
#  'priceHint': 2,
#  'sourceInterval': 15,
#  'exchange': 'NMS',
#  'regularMarketDayLow': 183.76,
#  'shortName': 'Tesla, Inc.',
#  'region': 'US',
#  'fiftyDayAverageChangePercent': -0.01592329,
#  'fullExchangeName': 'NasdaqGS',
#  'earningsTimestampStart': 1681815540,
#  'financialCurrency': 'USD',
#  'displayName': 'Tesla',
#  'gmtOffSetMilliseconds': -14400000,
#  'regularMarketOpen': 190.515,
#  'regularMarketTime': '2:16PM EDT',
#  'regularMarketChangePercent': -3.059198,
#  'quoteType': 'EQUITY',
#  'trailingAnnualDividendYield': 0.0,
#  'averageDailyVolume10Day': 132992460,
#  'fiftyTwoWeekLowChange': 84.8786,
#  'fiftyTwoWeekHighChangePercent': -0.48722255,
#  'typeDisp': 'Equity',
#  'trailingPE': 55.07038,
#  'tradeable': False,
#  'currency': 'USD',
#  'sharesOutstanding': 3164100096,
#  'regularMarketPreviousClose': 192.58,
#  'fiftyTwoWeekHigh': 364.07333,
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketChange': -5.891403,
#  'bidSize': 13,
#  'priceEpsCurrentYear': 47.86887,
#  'cryptoTradeable': False,
#  'fiftyDayAverage': 189.7094,
#  'epsCurrentYear': 3.9,
#  'exchangeTimezoneShortName': 'EDT',
#  'marketState': 'REGULAR',
#  'regularMarketPrice': 186.6886,
#  'customPriceAlertConfidence': 'HIGH',
#  'forwardPE': 34.129543,
#  'earningsTimestamp': 1674685800,
#  'ask': 186.66,
#  'epsTrailingTwelveMonths': 3.39,
#  'bid': 186.66,
#  'triggerable': True,
#  'priceToBook': 13.21315,
#  'longName': 'Tesla, Inc.',
#  'trailingPegRatio': None}

# %%
# sacar la informacion historica de 1 año hacia atras
hist = pfe.history(period="1mo")
hist['Date']=hist.index
hist=hist.reset_index(drop=True)
hist # tenemos 8 columnas
# Out:
#           Open        High         Low       Close     Volume  Dividends  \
# 0   198.539993  198.600006  192.300003  193.809998  128100100        0.0
# 1   191.380005  194.199997  186.100006  187.710007  148125800        0.0
# 2   185.039993  186.500000  180.000000  182.000000  151897800        0.0
# 3   180.250000  185.179993  172.509995  172.919998  170023800        0.0
# 4   175.130005  178.289993  168.440002  173.440002  191488900        0.0
# 5   167.460007  177.350006  163.910004  174.479996  167790300        0.0
# 6   177.309998  183.800003  177.139999  183.259995  143717900        0.0
# 7   180.800003  182.339996  176.029999  180.449997  145995600        0.0
# 8   180.369995  185.809998  178.839996  184.130005  121136800        0.0
# 9   184.520004  186.220001  177.330002  180.130005  133197100        0.0
# 10  178.080002  186.440002  176.350006  183.250000  129684400        0.0
# 11  188.279999  198.000000  188.039993  197.580002  153391400        0.0
# 12  199.300003  200.660004  190.949997  191.149994  150376400        0.0
# 13  195.259995  199.309998  188.649994  192.220001  144193900        0.0
# 14  191.649994  192.360001  187.149994  190.410004  116531600        0.0
# 15  194.419998  197.389999  189.940002  191.809998  120851600        0.0
# 16  192.000000  192.350006  185.429993  189.190002   98654600        0.0
# 17  193.130005  195.289993  189.440002  193.880005  123660000        0.0
# 18  195.580002  197.330002  194.419998  195.279999  110252200        0.0
# 19  197.529999  207.789993  197.199997  207.460007  169638500        0.0
# 20  199.910004  202.690002  192.199997  194.770004  169545900        0.0
# 21  197.320007  198.740005  190.320007  192.580002  126219900        0.0
# 22  190.514999  190.679993  183.759995  186.240295  103152667        0.0
#
#     Stock Splits                      Date
# 0            0.0 2023-03-06 00:00:00-05:00
# 1            0.0 2023-03-07 00:00:00-05:00
# 2            0.0 2023-03-08 00:00:00-05:00
# 3            0.0 2023-03-09 00:00:00-05:00
# 4            0.0 2023-03-10 00:00:00-05:00
# 5            0.0 2023-03-13 00:00:00-04:00
# 6            0.0 2023-03-14 00:00:00-04:00
# 7            0.0 2023-03-15 00:00:00-04:00
# 8            0.0 2023-03-16 00:00:00-04:00
# 9            0.0 2023-03-17 00:00:00-04:00
# 10           0.0 2023-03-20 00:00:00-04:00
# 11           0.0 2023-03-21 00:00:00-04:00
# 12           0.0 2023-03-22 00:00:00-04:00
# 13           0.0 2023-03-23 00:00:00-04:00
# 14           0.0 2023-03-24 00:00:00-04:00
# 15           0.0 2023-03-27 00:00:00-04:00
# 16           0.0 2023-03-28 00:00:00-04:00
# 17           0.0 2023-03-29 00:00:00-04:00
# 18           0.0 2023-03-30 00:00:00-04:00
# 19           0.0 2023-03-31 00:00:00-04:00
# 20           0.0 2023-04-03 00:00:00-04:00
# 21           0.0 2023-04-04 00:00:00-04:00
# 22           0.0 2023-04-05 00:00:00-04:00

# %% [markdown]
# # Paso 3

# %%
# Extaigamos graficos rapidos del ultimo año de precios de cierre de stocks IT
tickers = ['TSLA', 'META', 'AAPL','AMZN','GOOG'] # Tesla, MEta, Apple, Amazon y Google
import matplotlib.pyplot as plt
for i,ticker in enumerate(tickers):
  current_ticker = yf.Ticker(ticker)
  plt.subplot(len(tickers),1,i+1)
  current_ticker.history(period='365d')['Close'].plot(figsize=(16,60), title='Precio historico de 1 de un año para: '+ticker)

# %% [markdown]
# # Paso 4

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (1.4.32)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy) (1.1.1)

# %%
# !pip uninstall psycopg2-binary
# !pip uninstall psycopg2
# !pip install psycopg2
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.6-cp39-cp39-macosx_10_9_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 2.2 MB/s eta 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.6

# %%
url="data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws"
port="5439"
data_base="data-engineer-database"
user="hgr79_coderhouse"
# pwd="kye79Z96x3Xe"

with open("/Users/hernangonzalez/Downloads/pwd_coder.txt",'r') as f:
    pwd= f.read()

# %%
from sqlalchemy import create_engine
import pandas as pd
#conn = create_engine('postgresql://username:password@yoururl.com:5439/FINANZAS')
conn = create_engine(f'postgresql://{user}:{pwd}@{url}.com:5439/{data_base}')
# conn = create_engine(url=url, user=user, pwd=pwd, port=port, database=data_base)

# %%
conn
# Out:
# Engine(postgresql://hgr79_coderhouse:***@data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com:5439/data-engineer-database)

# %% [markdown]
# # Paso 5

# %%
goo = yf.Ticker('GOOG')
# sacar la informacion historica de 1 año hacia atras
hist = goo.history(period="1y")
hist['Date']=hist.index
hist=hist.reset_index(drop=True)
hist # tenemos 8 columnas
# Out:
#            Open        High         Low       Close    Volume  Dividends  \
# 0    139.161499  139.848495  136.418106  137.175995  23574000        0.0
# 1    136.617996  137.701508  134.857254  136.464996  19448000        0.0
# 2    136.250000  136.250000  133.752502  134.010498  16434000        0.0
# 3    132.899994  132.939194  129.617493  129.796494  24188000        0.0
# 4    132.423492  132.423492  127.575996  128.374496  23004000        0.0
# ..          ...         ...         ...         ...       ...        ...
# 246  101.440002  101.610001  100.290001  101.320000  25009800        0.0
# 247  101.709999  104.190002  101.440002  104.000000  28086500        0.0
# 248  102.669998  104.949997  102.379997  104.910004  20719900        0.0
# 249  104.839996  106.099998  104.599998  105.120003  20367700        0.0
# 250  106.120003  106.525002  104.105003  104.949997  21542589        0.0
#
#      Stock Splits                      Date
# 0             0.0 2022-04-06 00:00:00-04:00
# 1             0.0 2022-04-07 00:00:00-04:00
# 2             0.0 2022-04-08 00:00:00-04:00
# 3             0.0 2022-04-11 00:00:00-04:00
# 4             0.0 2022-04-12 00:00:00-04:00
# ..            ...                       ...
# 246           0.0 2023-03-30 00:00:00-04:00
# 247           0.0 2023-03-31 00:00:00-04:00
# 248           0.0 2023-04-03 00:00:00-04:00
# 249           0.0 2023-04-04 00:00:00-04:00
# 250           0.0 2023-04-05 00:00:00-04:00
#
# [251 rows x 8 columns]

# %% [markdown]
# # Paso 6

# %%
hist.to_sql('HIST_GOOG', conn, index=False, if_exists='replace',schema='hgr79_coderhouse')
# Out:
# /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1663: UserWarning: The provided table name 'HIST_GOOG' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# 252

# %% [markdown]
# # Mi codigo para el entregable de CoderHouse:

# %%
# !pip install sqlalchemy
# !pip install psycopg2-binary
# !pip install requests
# Out:
# Requirement already satisfied: sqlalchemy in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (1.4.32)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy) (1.1.1)
# Requirement already satisfied: psycopg2-binary in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (2.9.6)
# Requirement already satisfied: requests in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/hernangonzalez/opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)

# %%
url="data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws"
port="5439"
data_base="data-engineer-database"
user="hgr79_coderhouse"
# pwd="kye79Z96x3Xe"

with open("/Users/hernangonzalez/Downloads/pwd_coder.txt",'r') as f:
    pwd= f.read()

# %%
from sqlalchemy import create_engine
import pandas as pd
conn = create_engine(f'postgresql://{user}:{pwd}@{url}.com:5439/{data_base}')
# conn = create_engine(url=url, user=user, pwd=pwd, port=port, database=data_base)

# %%
conn
# Out:
# Engine(postgresql://hgr79_coderhouse:***@data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com:5439/data-engineer-database)

# %%
import requests

api_url = "https://api.websitecarbon.com/site?url=https%3A%2F%2Fwww.wholegraindigital.com%2F"
response = requests.get(api_url)
response.json()
# Out:
# {'url': 'https://www.wholegraindigital.com/',
#  'green': True,
#  'bytes': 332357,
#  'cleanerThan': 0.93,
#  'statistics': {'adjustedBytes': 250929.535,
#   'energy': 0.00018929403587244454,
#   'co2': {'grid': {'grams': 0.08366796385562049,
#     'litres': 0.04653612149649611},
#    'renewable': {'grams': 0.07253747454632076, 'litres': 0.0403453433426636}}},
#  'timestamp': 1680737133}

# %%
# pd_object = pd.read_json('astronomy_simple.json', typ='series')
df = pd.DataFrame(response.json())
display(df)
# Out:
#                                               url  green   bytes  cleanerThan  \
# adjustedBytes  https://www.wholegraindigital.com/   True  332357         0.93
# co2            https://www.wholegraindigital.com/   True  332357         0.93
# energy         https://www.wholegraindigital.com/   True  332357         0.93
#
#                                                       statistics   timestamp
# adjustedBytes                                         250929.535  1680737133
# co2            {'grid': {'grams': 0.08366796385562049, 'litre...  1680737133
# energy                                                  0.000189  1680737133

# %%
histt = df
histt['timestamp']=histt.index
histt=histt.reset_index(drop=True)
histt
# Out:
#                                   url  green   bytes  cleanerThan  \
# 0  https://www.wholegraindigital.com/   True  332357         0.93
# 1  https://www.wholegraindigital.com/   True  332357         0.93
# 2  https://www.wholegraindigital.com/   True  332357         0.93
#
#                                           statistics      timestamp
# 0                                         250929.535  adjustedBytes
# 1  {'grid': {'grams': 0.08366796385562049, 'litre...            co2
# 2                                           0.000189         energy

# %%
del histt['statistics']
histt
# Out:
#                                   url  green   bytes  cleanerThan  \
# 0  https://www.wholegraindigital.com/   True  332357         0.93
# 1  https://www.wholegraindigital.com/   True  332357         0.93
# 2  https://www.wholegraindigital.com/   True  332357         0.93
#
#        timestamp
# 0  adjustedBytes
# 1            co2
# 2         energy

# %%
histt.to_sql('WC', conn, index=False, if_exists='replace', schema='hgr79_coderhouse')
